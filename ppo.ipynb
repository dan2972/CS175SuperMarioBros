# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import imageio
import numpy as np
import matplotlib.pyplot as plt
import cv2
# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

from collections import deque

from torchvision import transforms as T

import gym
from gym.spaces import Box
from gym.wrappers import FrameStack

# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
env = gym_super_mario_bros.make("SuperMarioBros-v0")
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_1
# ----------------------------
# | time/              |     |
# |    fps             | 255 |
# |    iterations      | 1   |
# |    time_elapsed    | 2   |
# |    total_timesteps | 512 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 157          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 8.621719e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00415      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 128          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -5.47e-05    |
# |    value_loss           | 372          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 3.424834e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.000269    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 199          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000355    |
# |    value_loss           | 459          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 137          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 8.951768e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0299       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0862       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000619    |
# |    value_loss           | 3.04         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 133           |
# |    iterations           | 5             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 1.3471581e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0885        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.279         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000119     |
# |    value_loss           | 1.49          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 131           |
# |    iterations           | 6             |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 1.1155615e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00649      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.186         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -1.29e-05     |
# |    value_loss           | 1.25          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 129           |
# |    iterations           | 7             |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 1.2310338e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00388      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0977        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000148     |
# |    value_loss           | 0.643         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 128          |
# |    iterations           | 8            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 9.167939e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00497      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.146        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -9.37e-05    |
# |    value_loss           | 0.505        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 127           |
# |    iterations           | 9             |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 6.1036553e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00352      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.182         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000138     |
# |    value_loss           | 0.44          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 10           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 8.781557e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.000185     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.106        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000235    |
# |    value_loss           | 0.354        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 126           |
# |    iterations           | 11            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 1.3740151e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00402       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.107         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000325     |
# |    value_loss           | 0.239         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 12           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 4.692236e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00154     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.113        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -9.33e-05    |
# |    value_loss           | 0.344        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 125           |
# |    iterations           | 13            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 1.9687926e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00353       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0672        |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000355     |
# |    value_loss           | 0.171         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 14           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 9.496696e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0141       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 27.5         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000139    |
# |    value_loss           | 79.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 125           |
# |    iterations           | 15            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 5.0310045e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0636       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.201         |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -8.01e-05     |
# |    value_loss           | 0.63          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 124           |
# |    iterations           | 16            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 6.2169274e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0227        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.136         |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000115     |
# |    value_loss           | 0.41          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 124           |
# |    iterations           | 17            |
# |    time_elapsed         | 69            |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 4.8468355e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.04          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0811        |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000119     |
# |    value_loss           | 0.316         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 18           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 3.640901e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0288       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 97           |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000318    |
# |    value_loss           | 212          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 124           |
# |    iterations           | 19            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 0.00010564015 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0212        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 78.7          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000228     |
# |    value_loss           | 204           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 123           |
# |    iterations           | 20            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 1.6215723e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0354        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.116         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 7.12e-05      |
# |    value_loss           | 2.57          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 123           |
# |    iterations           | 21            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 5.2176183e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0329       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.239         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 9.94e-05      |
# |    value_loss           | 1.26          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 22           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 8.348376e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0571       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.197        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.000149     |
# |    value_loss           | 1.12         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 23           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 7.456634e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0859      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.137        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 6.93e-05     |
# |    value_loss           | 0.757        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 24           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 8.144532e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0511      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.273        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -8.47e-05    |
# |    value_loss           | 0.909        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 25            |
# |    time_elapsed         | 104           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 7.6128636e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00426      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.142         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -6.31e-05     |
# |    value_loss           | 0.457         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 26            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 7.3265983e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00716       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.248         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -4.89e-05     |
# |    value_loss           | 0.847         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 27           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 6.683753e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00168     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.166        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000104    |
# |    value_loss           | 0.347        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 28            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 1.7427374e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0175       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0555        |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000243     |
# |    value_loss           | 0.165         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 29           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 14848        |
# | train/                  |              |
# |    approx_kl            | 1.121941e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00827      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.115        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00015     |
# |    value_loss           | 0.241        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 30            |
# |    time_elapsed         | 125           |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 1.0565855e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00108      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.11          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000139     |
# |    value_loss           | 0.21          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 31            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 15872         |
# | train/                  |               |
# |    approx_kl            | 2.4858979e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00684      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0955        |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000335     |
# |    value_loss           | 0.2           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 32            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 3.1687785e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0053        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0861        |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000327     |
# |    value_loss           | 0.237         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 33           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 6.330176e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00322      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0837       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00082     |
# |    value_loss           | 0.183        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 34           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 4.580128e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0286       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 194          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000326    |
# |    value_loss           | 517          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 35           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 17920        |
# | train/                  |              |
# |    approx_kl            | 8.798088e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0294       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0759       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 2.65e-05     |
# |    value_loss           | 0.611        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 36            |
# |    time_elapsed         | 150           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.1620577e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0355        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0967        |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000129     |
# |    value_loss           | 0.312         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 37            |
# |    time_elapsed         | 154           |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 1.4282181e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.062         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0753        |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000175     |
# |    value_loss           | 0.264         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 38            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 1.1297525e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0506        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0987        |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000103     |
# |    value_loss           | 0.33          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 39           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 19968        |
# | train/                  |              |
# |    approx_kl            | 9.583309e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.132        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000135    |
# |    value_loss           | 0.349        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 40            |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 1.7602113e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0125        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0747        |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000239     |
# |    value_loss           | 0.186         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 41            |
# |    time_elapsed         | 172           |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 2.0246021e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00206       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0462        |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000282     |
# |    value_loss           | 0.118         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 42            |
# |    time_elapsed         | 176           |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 1.7390936e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0141       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0796        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000255     |
# |    value_loss           | 0.151         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 43            |
# |    time_elapsed         | 180           |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 1.1143275e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0169       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0578        |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000163     |
# |    value_loss           | 0.189         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 44            |
# |    time_elapsed         | 184           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 2.0439038e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0122       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0698        |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000227     |
# |    value_loss           | 0.149         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 45            |
# |    time_elapsed         | 188           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 2.4739187e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00492       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0422        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000323     |
# |    value_loss           | 0.153         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 46            |
# |    time_elapsed         | 192           |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 1.1994038e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.012         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.055         |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000137     |
# |    value_loss           | 0.131         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 47            |
# |    time_elapsed         | 197           |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 9.0620015e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.000779     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.107         |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000119     |
# |    value_loss           | 0.186         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 48            |
# |    time_elapsed         | 201           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.8915161e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00786       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.202         |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000318     |
# |    value_loss           | 0.481         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 49           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 3.190746e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.939        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000189    |
# |    value_loss           | 2.45         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 50            |
# |    time_elapsed         | 209           |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 0.00019252009 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0383        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 175           |
# |    n_updates            | 490           |
# |    policy_gradient_loss | 0.000229      |
# |    value_loss           | 441           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 51            |
# |    time_elapsed         | 214           |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 4.4663902e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.16          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.194         |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000227     |
# |    value_loss           | 1.01          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 52            |
# |    time_elapsed         | 218           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.1058291e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0219       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.107         |
# |    n_updates            | 510           |
# |    policy_gradient_loss | 0.000106      |
# |    value_loss           | 0.512         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 53            |
# |    time_elapsed         | 222           |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 1.2895209e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00937       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.132         |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -5.56e-05     |
# |    value_loss           | 0.419         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 54            |
# |    time_elapsed         | 226           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 0.00014515116 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.059         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 26.6          |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.00013      |
# |    value_loss           | 74.5          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 55            |
# |    time_elapsed         | 231           |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 4.5360648e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0728        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.143         |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -7.42e-05     |
# |    value_loss           | 0.528         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 56            |
# |    time_elapsed         | 235           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 7.3028496e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0233       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.137         |
# |    n_updates            | 550           |
# |    policy_gradient_loss | 0.000179      |
# |    value_loss           | 0.458         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 57            |
# |    time_elapsed         | 239           |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 1.3508135e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0157        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.139         |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -3.24e-05     |
# |    value_loss           | 0.368         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 58            |
# |    time_elapsed         | 243           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 3.6716112e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0336        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.123         |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000448     |
# |    value_loss           | 0.322         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 59            |
# |    time_elapsed         | 248           |
# |    total_timesteps      | 30208         |
# | train/                  |               |
# |    approx_kl            | 2.1227053e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.257         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.135         |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000136     |
# |    value_loss           | 0.343         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 60            |
# |    time_elapsed         | 252           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.4341553e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.33          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.104         |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.00015      |
# |    value_loss           | 0.256         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 61           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 31232        |
# | train/                  |              |
# |    approx_kl            | 1.830177e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.196        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.128        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.000182    |
# |    value_loss           | 0.152        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 62           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 5.700905e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0886       |
# |    learning_rate        | 1e-06        |
# ...
# |    approx_kl            | 0.0002653856 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 133          |
# |    n_updates            | 15600        |
# |    policy_gradient_loss | -0.000542    |
# |    value_loss           | 181          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 1562         |
# |    time_elapsed         | 6852         |
# |    total_timesteps      | 799744       |
# | train/                  |              |
# |    approx_kl            | 0.0006150373 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | -0.112       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 3.22         |
# |    n_updates            | 15610        |
# |    policy_gradient_loss | 0.00518      |
# |    value_loss           | 52.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 1563         |
# |    time_elapsed         | 6856         |
# |    total_timesteps      | 800256       |
# | train/                  |              |
# |    approx_kl            | 0.0013963875 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.656       |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 185          |
# |    n_updates            | 15620        |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 408          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 1564         |
# |    time_elapsed         | 6860         |
# |    total_timesteps      | 800768       |
# | train/                  |              |
# |    approx_kl            | 0.0011178602 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.577       |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 145          |
# |    n_updates            | 15630        |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 224          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 1565         |
# |    time_elapsed         | 6864         |
# |    total_timesteps      | 801280       |
# | train/                  |              |
# |    approx_kl            | 8.832163e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 89.9         |
# |    n_updates            | 15640        |
# |    policy_gradient_loss | 0.000249     |
# |    value_loss           | 236          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 52            |
# |    iterations           | 1566          |
# |    time_elapsed         | 15193         |
# |    total_timesteps      | 801792        |
# | train/                  |               |
# |    approx_kl            | 0.00062145374 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.543        |
# |    explained_variance   | 0.398         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 190           |
# |    n_updates            | 15650         |
# |    policy_gradient_loss | -0.000633     |
# |    value_loss           | 988           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 1567         |
# |    time_elapsed         | 15197        |
# |    total_timesteps      | 802304       |
# | train/                  |              |
# |    approx_kl            | 0.0005839906 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 62.5         |
# |    n_updates            | 15660        |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 158          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 1568         |
# |    time_elapsed         | 15202        |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0007478462 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 86.1         |
# |    n_updates            | 15670        |
# |    policy_gradient_loss | -0.000785    |
# |    value_loss           | 214          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 52            |
# |    iterations           | 1569          |
# |    time_elapsed         | 15206         |
# |    total_timesteps      | 803328        |
# | train/                  |               |
# |    approx_kl            | 0.00019808614 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.501        |
# |    explained_variance   | 0.495         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 390           |
# |    n_updates            | 15680         |
# |    policy_gradient_loss | -0.00132      |
# |    value_loss           | 943           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 1570         |
# |    time_elapsed         | 15210        |
# |    total_timesteps      | 803840       |
# | train/                  |              |
# |    approx_kl            | 0.0012430501 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.623       |
# |    explained_variance   | 0.89         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 88.2         |
# |    n_updates            | 15690        |
# |    policy_gradient_loss | -0.000293    |
# |    value_loss           | 207          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 1571         |
# |    time_elapsed         | 15214        |
# |    total_timesteps      | 804352       |
# | train/                  |              |
# |    approx_kl            | 0.0011368239 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 49.1         |
# |    n_updates            | 15700        |
# |    policy_gradient_loss | 0.000618     |
# |    value_loss           | 119          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 1572        |
# |    time_elapsed         | 15218       |
# |    total_timesteps      | 804864      |
# | train/                  |             |
# |    approx_kl            | 0.004382505 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 50.5        |
# |    n_updates            | 15710       |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 169         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 52            |
# |    iterations           | 1573          |
# |    time_elapsed         | 15222         |
# |    total_timesteps      | 805376        |
# | train/                  |               |
# |    approx_kl            | 0.00039365212 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.592        |
# |    explained_variance   | 0.498         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 479           |
# |    n_updates            | 15720         |
# |    policy_gradient_loss | 9.78e-05      |
# |    value_loss           | 984           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 1574         |
# |    time_elapsed         | 15226        |
# |    total_timesteps      | 805888       |
# | train/                  |              |
# |    approx_kl            | 0.0004218222 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 71.6         |
# |    n_updates            | 15730        |
# |    policy_gradient_loss | -0.000533    |
# |    value_loss           | 133          |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\dan2972\Desktop\UCI\Fall 2023\CS175\PPO.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/dan2972/Desktop/UCI/Fall%202023/CS175/PPO.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Train the AI model, this is where the AI model starts to learn
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dan2972/Desktop/UCI/Fall%202023/CS175/PPO.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> model.learn(total_timesteps=1000000, callback=callback)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\ppo\ppo.py:310, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297 def learn(
#     298     self,
#     299     total_timesteps: int,
#    (...)
#     307     reset_num_timesteps: bool = True,
#     308 ) -> "PPO":
# --> 310     return super().learn(
#     311         total_timesteps=total_timesteps,
#     312         callback=callback,
#     313         log_interval=log_interval,
#     314         eval_env=eval_env,
#     315         eval_freq=eval_freq,
#     316         n_eval_episodes=n_eval_episodes,
#     317         tb_log_name=tb_log_name,
#     318         eval_log_path=eval_log_path,
#     319         reset_num_timesteps=reset_num_timesteps,
#     320     )
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:247, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     243 callback.on_training_start(locals(), globals())
#     245 while self.num_timesteps < total_timesteps:
# --> 247     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     249     if continue_training is False:
#     250         break
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:166, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     163 with th.no_grad():
#     164     # Convert to pytorch tensor or to TensorDict
#     165     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 166     actions, values, log_probs = self.policy(obs_tensor)
#     167 actions = actions.cpu().numpy()
#     169 # Rescale and perform action
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\policies.py:592, in ActorCriticPolicy.forward(self, obs, deterministic)
#     590 # Evaluate the values for the given observations
#     591 values = self.value_net(latent_vf)
# --> 592 distribution = self._get_action_dist_from_latent(latent_pi)
#     593 actions = distribution.get_actions(deterministic=deterministic)
#     594 log_prob = distribution.log_prob(actions)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\policies.py:610, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     607     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     608 elif isinstance(self.action_dist, CategoricalDistribution):
#     609     # Here mean_actions are the logits before the softmax
# --> 610     return self.action_dist.proba_distribution(action_logits=mean_actions)
#     611 elif isinstance(self.action_dist, MultiCategoricalDistribution):
#     612     # Here mean_actions are the flattened logits
#     613     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\distributions.py:275, in CategoricalDistribution.proba_distribution(self, action_logits)
#     274 def proba_distribution(self, action_logits: th.Tensor) -> "CategoricalDistribution":
# --> 275     self.distribution = Categorical(logits=action_logits)
#     276     return self
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\torch\distributions\categorical.py:64, in Categorical.__init__(self, probs, logits, validate_args)
#      62         raise ValueError("`logits` parameter must be at least one-dimensional.")
#      63     # Normalize
# ---> 64     self.logits = logits - logits.logsumexp(dim=-1, keepdim=True)
#      65 self._param = self.probs if probs is not None else self.logits
#      66 self._num_events = self._param.size()[-1]
#
# KeyboardInterrupt:

# %%
model.save('thisisatestmodel')

# %%
# Load model
model = PPO.load('./train/best_model_1000000')
state = env.reset()
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\dan2972\Desktop\UCI\Fall 2023\CS175\PPO.ipynb Cell 10 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/dan2972/Desktop/UCI/Fall%202023/CS175/PPO.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # Load model
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dan2972/Desktop/UCI/Fall%202023/CS175/PPO.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> model = PPO.load('./train/best_model_1000000')
#       <a href='vscode-notebook-cell:/c%3A/Users/dan2972/Desktop/UCI/Fall%202023/CS175/PPO.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> state = env.reset()
#       <a href='vscode-notebook-cell:/c%3A/Users/dan2972/Desktop/UCI/Fall%202023/CS175/PPO.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> # Start the game
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\base_class.py:704, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     701     print("== CURRENT SYSTEM INFO ==")
#     702     get_system_info()
# --> 704 data, params, pytorch_variables = load_from_zip_file(
#     705     path, device=device, custom_objects=custom_objects, print_system_info=print_system_info
#     706 )
#     708 # Remove stored device information and replace with ours
#     709 if "policy_kwargs" in data:
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\save_util.py:388, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     361 def load_from_zip_file(
#     362     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     363     load_data: bool = True,
#    (...)
#     367     print_system_info: bool = False,
#     368 ) -> (Tuple[Optional[Dict[str, Any]], Optional[TensorDict], Optional[TensorDict]]):
#     369     """
#     370     Load model data from a .zip archive
#     371
#    (...)
#     386         and dict of pytorch variables
#     387     """
# --> 388     load_path = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     390     # set device to cpu if cuda is not available
#     391     device = get_device(device=device)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\save_util.py:232, in open_path_str(path, mode, verbose, suffix)
#     217 @open_path.register(str)
#     218 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     219     """
#     220     Open a path given by a string. If writing to the path, the function ensures
#     221     that the path exists.
#    (...)
#     230     :return:
#     231     """
# --> 232     return open_path(pathlib.Path(path), mode, verbose, suffix)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\save_util.py:284, in open_path_pathlib(path, mode, verbose, suffix)
#     277         path.parent.mkdir(exist_ok=True, parents=True)
#     279 # if opening was successful uses the identity function
#     280 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     281 #   with corrections
#     282 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 284 return open_path(path, mode, verbose, suffix)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\save_util.py:264, in open_path_pathlib(path, mode, verbose, suffix)
#     262             path, suffix = newpath, None
#     263         else:
# --> 264             raise error
#     265 else:
#     266     try:
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\site-packages\stable_baselines3\common\save_util.py:256, in open_path_pathlib(path, mode, verbose, suffix)
#     254 if mode == "r":
#     255     try:
# --> 256         path = path.open("rb")
#     257     except FileNotFoundError as error:
#     258         if suffix is not None and suffix != "":
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\pathlib.py:1252, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1246 def open(self, mode='r', buffering=-1, encoding=None,
#    1247          errors=None, newline=None):
#    1248     """
#    1249     Open the file pointed by this path and return a file object, as
#    1250     the built-in open() function does.
#    1251     """
# -> 1252     return io.open(self, mode, buffering, encoding, errors, newline,
#    1253                    opener=self._opener)
#
# File c:\Users\dan2972\miniconda3\envs\rltest\lib\pathlib.py:1120, in Path._opener(self, name, flags, mode)
#    1118 def _opener(self, name, flags, mode=0o666):
#    1119     # A stub for the opener argument to built-in open()
# -> 1120     return self._accessor.open(self, flags, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train\\best_model_1000000.zip'

# %%
def record_video(env, model, out_directory, fps=30, max_frames = 1000):
  images = []
  done = False
  state, _ = env.reset()
  frame_counter = 0
  while not done and frame_counter < max_frames:
    action, _ = model.predict(state)
    state, reward, done, tunc, info = env.step(action)
    img = env.render()
    x = img.copy()
    images.append(x)
    frame_counter += 1
  imageio.mimsave(out_directory, [np.array(img) for img in images], fps=fps)

# %%
record_video(env, model, './replay.mp4', 30)
